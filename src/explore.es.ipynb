# %% [markdown]
# # Explora aquí
#
# Se recomienda utilizar este cuaderno con fines de exploración.

# %%
import os
from bs4 import BeautifulSoup
import requests
import time
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from datetime import datetime
import time
import base64
import json

# %%
BASE_URL_SKINCARE = "https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}"
BASE_URL_MAKEUP = "https://www.maquillajetrendyshop.com/maquillaje/rostro?page={}"

# %%
HEADERS = {
    "User-Agent": "Mozilla/5.0"
}

# %%
def category(base_url, category_name):
    headers = {
        "User-Agent": "Mozilla/5.0"
    }

    products = []
    page = 1

    while True:
        url = f"{base_url}?page={page}"
        print("Scrapeando:", url)

        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.text, "lxml")

        items = soup.find_all("section", attrs={"aria-label": True})

        if not items:
            print("No se encontraron más productos.")
            break

        for item in items:
            name = item.get("aria-label")

            products.append({
                "categoria": category_name,
                "producto": name
            })

        page += 1

    return products

# %%
print("Iniciando scraping...\n")

skincare_data = category(BASE_URL_SKINCARE, "Cuidado Facial")
makeup_data = category(BASE_URL_MAKEUP, "Maquillaje Rostro")

data = skincare_data + makeup_data

df = pd.DataFrame(data)
df
# Out:
# Iniciando scraping...
#
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=1
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=2
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=3
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=4
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=5
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=6
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=7
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=8
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=9
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=10
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=11
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=12
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=13
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=14
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=15
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=16
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=17
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=18
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=19
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=20
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=21
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=22
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=23
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=24
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=25
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=26
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=27
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=28
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=29
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=30
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=31
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=32
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=33
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=34
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=35
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=36
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=37
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=38
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=39
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=40
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=41
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=42
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=43
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=44
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=45
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=46
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=47
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=48
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=49
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=50
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=51
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=52
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=53
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=54
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=55
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=56
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=57
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=58
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=59
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=60
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=61
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=62
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=63
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=64
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=65
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=66
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=67
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=68
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=69
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=70
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=71
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=72
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=73
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=74
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=75
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=76
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=77
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=78
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=79
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=80
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=81
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=82
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=83
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=84
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=85
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=86
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=87
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=88
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=89
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=90
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=91
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=92
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=93
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=94
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=95
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=96
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=97
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=98
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=99
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=100
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=101
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=102
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=103
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=104
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=105
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=106
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=107
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=108
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=109
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=110
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=111
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=112
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=113
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=114
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=115
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=116
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=117
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=118
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=119
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=120
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=121
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=122
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=123
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=124
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=125
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=126
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=127
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=128
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=129
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=130
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=131
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=132
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=133
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=134
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=135
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=136
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=137
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=138
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=139
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=140
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=141
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=142
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=143
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=144
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=145
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=146
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=147
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=148
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=149
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=150
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=151
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=152
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=153
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=154
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=155
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=156
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=157
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=158
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=159
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=160
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=161
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=162
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=163
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=164
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=165
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=166
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=167
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=168
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=169
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=170
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=171
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=172
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=173
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=174
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=175
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=176
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=177
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=178
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=179
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=180
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=181
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=182
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=183
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=184
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=185
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=186
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=187
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=188
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=189
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=190
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=191
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=192
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=193
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=194
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=195
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=196
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=197
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=198
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=199
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=200
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=201
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=202
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=203
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=204
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=205
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=206
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=207
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=208
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=209
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=210
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=211
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=212
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=213
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=214
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=215
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=216
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=217
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=218
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=219
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=220
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=221
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=222
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=223
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=224
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=225
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=226
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=227
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=228
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=229
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=230
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=231
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=232
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=233
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=234
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=235
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=236
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=237
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=238
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=239
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=240
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=241
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=242
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=243
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=244
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=245
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=246
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=247
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=248
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=249
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=250
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=251
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=252
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=253
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=254
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=255
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=256
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=257
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=258
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=259
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=260
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=261
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=262
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=263
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=264
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=265
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=266
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=267
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=268
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=269
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=270
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=271
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=272
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=273
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=274
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=275
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=276
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=277
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=278
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=279
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=280
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=281
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=282
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=283
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=284
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=285
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=286
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=287
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=288
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=289
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=290
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=291
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=292
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=293
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=294
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=295
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=296
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=297
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=298
# Scrapeando: https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page={}?page=299
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 print("Iniciando scraping...\n")
# ----> 3 skincare_data = category(BASE_URL_SKINCARE, "Cuidado Facial")
#       4 makeup_data = category(BASE_URL_MAKEUP, "Maquillaje Rostro")
#       6 data = skincare_data + makeup_data
#
# Cell In[7], line 13, in category(base_url, category_name)
#      10 url = f"{base_url}?page={page}"
#      11 print("Scrapeando:", url)
# ---> 13 response = requests.get(url, headers=headers)
#      14 soup = BeautifulSoup(response.text, "lxml")
#      16 items = soup.find_all("section", attrs={"aria-label": True})
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\urllib3\connection.py:571, in HTTPConnection.getresponse(self)
#     568 _shutdown = getattr(self.sock, "shutdown", None)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#     574     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\http\client.py:1450, in HTTPConnection.getresponse(self)
#    1448 try:
#    1449     try:
# -> 1450         response.begin()
#    1451     except ConnectionError:
#    1452         self.close()
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\http\client.py:336, in HTTPResponse.begin(self)
#     334 # read until we get a non-100 response
#     335 while True:
# --> 336     version, status, reason = self._read_status()
#     337     if status != CONTINUE:
#     338         break
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\http\client.py:297, in HTTPResponse._read_status(self)
#     296 def _read_status(self):
# --> 297     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     298     if len(line) > _MAXLINE:
#     299         raise LineTooLong("status line")
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\socket.py:725, in SocketIO.readinto(self, b)
#     723     raise OSError("cannot read from timed out object")
#     724 try:
# --> 725     return self._sock.recv_into(b)
#     726 except timeout:
#     727     self._timeout_occurred = True
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import requests

url = "https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page=1"

response = requests.get(url)

print(response.text[:2000])
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\urllib3\connection.py:204, in HTTPConnection._new_conn(self)
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\socket.py:983, in getaddrinfo(host, port, family, type, proto, flags)
#     982 addrlist = []
# --> 983 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     984     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\urllib3\connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\urllib3\connection.py:759, in HTTPSConnection.connect(self)
#     758 sock: socket.socket | ssl.SSLSocket
# --> 759 self.sock = sock = self._new_conn()
#     760 server_hostname: str = self.host
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\urllib3\connection.py:211, in HTTPConnection._new_conn(self)
#     210 except socket.gaierror as e:
# --> 211     raise NameResolutionError(self.host, self, e) from e
#     212 except SocketTimeout as e:
#
# NameResolutionError: HTTPSConnection(host='www.maquillajetrendyshop.com', port=443): Failed to resolve 'www.maquillajetrendyshop.com' ([Errno 11001] getaddrinfo failed)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\urllib3\util\retry.py:535, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     534     reason = error or ResponseError(cause)
# --> 535     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     537 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='www.maquillajetrendyshop.com', port=443): Max retries exceeded with url: /cuidado-de-la-piel/cuidado-facial?page=1 (Caused by NameResolutionError("HTTPSConnection(host='www.maquillajetrendyshop.com', port=443): Failed to resolve 'www.maquillajetrendyshop.com' ([Errno 11001] getaddrinfo failed)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[10], line 5
#       1 import requests
#       3 url = "https://www.maquillajetrendyshop.com/cuidado-de-la-piel/cuidado-facial?page=1"
# ----> 5 response = requests.get(url)
#       7 print(response.text[:2000])
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\nata1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\requests\adapters.py:677, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     673     if isinstance(e.reason, _SSLError):
#     674         # This branch is for urllib3 v1.22 and later.
#     675         raise SSLError(e, request=request)
# --> 677     raise ConnectionError(e, request=request)
#     679 except ClosedPoolError as e:
#     680     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='www.maquillajetrendyshop.com', port=443): Max retries exceeded with url: /cuidado-de-la-piel/cuidado-facial?page=1 (Caused by NameResolutionError("HTTPSConnection(host='www.maquillajetrendyshop.com', port=443): Failed to resolve 'www.maquillajetrendyshop.com' ([Errno 11001] getaddrinfo failed)"))

# %%
import requests
import base64
import json

url = "https://www.maquillajetrendyshop.com/_v/segment/graphql/v1"

headers = {
    "User-Agent": "Mozilla/5.0",
    "Content-Type": "application/json"
}

# Construimos variables dinámicamente
variables_dict = {
    "hideUnavailableItems": False,
    "skusFilter": "ALL",
    "simulationBehavior": "skip",
    "installmentCriteria": "MAX_WITHOUT_INTEREST",
    "productOriginVtex": False,
    "map": "c,c",
    "query": "maquillaje/rostro",
    "orderBy": "OrderByReleaseDateDESC",
    "from": 0,
    "to": 9,
    "selectedFacets": [
        {"key": "c", "value": "maquillaje"},
        {"key": "c", "value": "rostro"}
    ],
    "operator": "and",
    "fuzzy": "0",
    "searchState": None,
    "facetsBehavior": "Static",
    "categoryTreeBehavior": "default",
    "withFacets": False
}

# Convertimos a base64
variables_encoded = base64.b64encode(json.dumps(variables_dict).encode()).decode()

params = {
    "workspace": "master",
    "maxAge": "short",
    "appsEtag": "remove",
    "domain": "store",
    "locale": "es-CO",
    "__bindingId": "762e992d-a355-4c7e-b34c-1657f86d5cca",
    "operationName": "productSearchV3",
    "variables": "{}",
    "extensions": json.dumps({
        "persistedQuery": {
            "version": 1,
            "sha256Hash": "31d3fa494df1fc41efef6d16dd96a96e6911b8aed7a037868699a1f3f4d365de",
            "sender": "vtex.store-resources@0.x",
            "provider": "vtex.search-graphql@0.x"
        },
        "variables": variables_encoded
    })
}

response = requests.get(url, headers=headers, params=params)

data = response.json()

print(data)
# Out:
# {'data': {'productSearch': {'products': [{'advertisement': None, 'cacheId': 'sp-917', 'productId': '917', 'description': 'El kit esencial para lograr una piel uniforme, iluminada y natural. Ideal para corregir, resaltar y sellar el maquillaje en pocos pasos, adaptándose a tu rutina diaria.<br/><br/>Incluye un corrector en barra de baja cobertura, perfecto para aportar puntos de luz y un acabado fresco; un corrector líquido de cobertura media, ideal para corregir y neutralizar ojeras e imperfecciones; y un polvo compacto que aporta color y ayuda a sellar los productos líquidos y en crema, prolongando su duración.', 'productName': 'Kit Piel Mistic Face Ref KMF2247', 'productReference': None, 'linkText': 'kit-piel-mistic-face-kmf2247', 'brand': 'Trendy', 'brandId': 2000000, 'link': '/kit-piel-mistic-face-kmf2247/p', 'categories': ['/Maquillaje/Rostro/Correctores/', '/Maquillaje/Rostro/', '/Maquillaje/', '/Maquillaje/Rostro/Polvos/'], 'categoryId': '4', 'releaseDate': '1769817600000', 'priceRange': {'sellingPrice': {'highPrice': 20000, 'lowPrice': 20000, '__typename': 'PriceRange'}, 'listPrice': {'highPrice': 20000, 'lowPrice': 20000, '__typename': 'PriceRange'}, '__typename': 'ProductPriceRange'}, 'specificationGroups': [{'name': 'Especificaciones de filtro', 'originalName': 'Especificaciones de filtro', 'specifications': [{'name': 'Tipo de piel', 'originalName': 'Tipo de piel', 'values': ['Todo tipo de piel'], '__typename': 'SpecificationGroupProperty'}, {'name': 'Acabado', 'originalName': 'Acabado', 'values': ['Mate'], '__typename': 'SpecificationGroupProperty'}, {'name': 'Tipo de polvo', 'originalName': 'Tipo de polvo', 'values': ['Compacto'], '__typename': 'SpecificationGroupProperty'}, {'name': 'Cobertura', 'originalName': 'Cobertura', 'values': ['Media'], '__typename': 'SpecificationGroupProperty'}, {'name': 'Tonalidad', 'originalName': 'Tonalidad', 'values': ['Cálido'], '__typename': 'SpecificationGroupProperty'}], '__typename': 'SpecificationGroup'}, {'name': 'Especificaciones de contenido', 'originalName': 'Especificaciones de contenido', 'specifications': [{'name': 'Cantidad mínima', 'originalName': 'Cantidad mínima', 'values': ['1'], '__typename': 'SpecificationGroupProperty'}, {'name': 'Modo de uso', 'originalName': 'Modo de uso', 'values': ['Modo de uso:\nAplica el corrector líquido o en barra sobre la zona a maquillar y difumina con brocha o esponja. Finaliza sellando con el polvo compacto para un acabado más uniforme y duradero.'], '__typename': 'SpecificationGroupProperty'}, {'name': 'Cuidados', 'originalName': 'Cuidados', 'values': ['Almacenar en un lugar fresco, seco y alejado de la luz solar directa.'], '__typename': 'SpecificationGroupProperty'}, {'name': 'Registro Invima', 'originalName': 'Registro Invima', 'values': ['NSOC35499-24CO'], '__typename': 'SpecificationGroupProperty'}, {'name': 'Beneficios', 'originalName': 'Beneficios', 'values': ['Aportan un acabado natural.'], '__typename': 'SpecificationGroupProperty'}, {'name': 'Contenido', 'originalName': 'Contenido', 'values': ['Corrector en barra: 3 g Corrector líquido: 4 ml Polvo compacto: 4 g'], '__typename': 'SpecificationGroupProperty'}, {'name': 'Presentación', 'originalName': 'Presentación', 'values': ['Kit'], '__typename': 'SpecificationGroupProperty'}, {'name': 'Garantía', 'originalName': 'Garantía', 'values': ['30 días'], '__typename': 'SpecificationGroupProperty'}, {'name': 'Información adicional', 'originalName': 'Información adicional', 'values': ['Es un kit escencial'], '__typename': 'SpecificationGroupProperty'}], '__typename': 'SpecificationGroup'}, {'name': 'allSpecifications', 'originalName': 'allSpecifications', 'specifications': [{'name': 'Tipo de piel', 'originalName': 'Tipo de piel', 'values': ['Todo tipo de piel'], '__typename': 'SpecificationGroupProperty'}, {'name': 'Acabado', 'originalName': 'Acabado', 'values': ['Mate'], '__typename': 'SpecificationGroupProperty'}, {'name': 'Tipo de polvo', 'originalName': 'Tipo de polvo', 'values ...

# %%
products = data["data"]["productSearch"]["products"]

for p in products:
    print(p["productName"])
# Out:
# Kit Piel Mistic Face Ref KMF2247
# Kit Mini Favoritos Galaxy 2026 Ref KMF2454
# Pin Stitch Guitarra DY2346
# Kit Rubor y Gloss Pinky News Ref KPN2248
# Corrector Hidrante Rebel Girl Ref CRG1420
# Esponja Panda Ref EPT2411
# Rubor En Barra Barbie Vaquera Ref MT2381
# Corrector De Ojeras Aura Ref CTT2229
# Tinta Rubor Barbie Malibu Ref MT2260
# Iluminador Líquido Panda Ref ILK2286

# %% [markdown]
# # Respuesta final

# %%
url = "https://www.maquillajetrendyshop.com/_v/segment/graphql/v1"

headers = {
    "User-Agent": "Mozilla/5.0",
    "Content-Type": "application/json"
}

# %%
def scrape_category(query_path, facet1, facet2, category_name):
    all_products = []
    page = 0
    page_size = 10

    print(f"\nScrapeando categoría: {category_name}")

    while True:
        from_value = page * page_size
        to_value = from_value + page_size - 1

        variables_dict = {
            "hideUnavailableItems": False,
            "skusFilter": "ALL",
            "simulationBehavior": "skip",
            "installmentCriteria": "MAX_WITHOUT_INTEREST",
            "productOriginVtex": False,
            "map": "c,c",
            "query": query_path,
            "orderBy": "OrderByReleaseDateDESC",
            "from": from_value,
            "to": to_value,
            "selectedFacets": [
                {"key": "c", "value": facet1},
                {"key": "c", "value": facet2}
            ],
            "operator": "and",
            "fuzzy": "0",
            "searchState": None,
            "facetsBehavior": "Static",
            "categoryTreeBehavior": "default",
            "withFacets": False
        }

        variables_encoded = base64.b64encode(
            json.dumps(variables_dict).encode()
        ).decode()

        params = {
            "workspace": "master",
            "maxAge": "short",
            "appsEtag": "remove",
            "domain": "store",
            "locale": "es-CO",
            "__bindingId": "762e992d-a355-4c7e-b34c-1657f86d5cca",
            "operationName": "productSearchV3",
            "extensions": json.dumps({
                "persistedQuery": {
                    "version": 1,
                    "sha256Hash": "31d3fa494df1fc41efef6d16dd96a96e6911b8aed7a037868699a1f3f4d365de",
                    "sender": "vtex.store-resources@0.x",
                    "provider": "vtex.search-graphql@0.x"
                },
                "variables": variables_encoded
            })
        }

        response = requests.get(url, headers=headers, params=params)
        data = response.json()

        products = data["data"]["productSearch"]["products"]

        if not products:
            print("Fin de categoría.")
            break

        for p in products:
            try:
                name = p["productName"]
                brand = p.get("brand")
                price = p["items"][0]["sellers"][0]["commertialOffer"]["Price"]
                list_price = p["items"][0]["sellers"][0]["commertialOffer"]["ListPrice"]

                all_products.append({
                    "name": name,
                    "brand": brand,
                    "price": price,
                    "list_price": list_price,
                    "category": category_name
                })
            except:
                continue

        print(f"Página {page+1} procesada")
        page += 1
        time.sleep(1)

    return pd.DataFrame(all_products)

# %%
makeup_df = scrape_category(
    "maquillaje/rostro",
    "maquillaje",
    "rostro",
    "Maquillaje Rostro"
)
# Out:
# Scrapeando categoría: Maquillaje Rostro
# Página 1 procesada
# Página 2 procesada
# Página 3 procesada
# Página 4 procesada
# Página 5 procesada
# Página 6 procesada
# Página 7 procesada
# Fin de categoría.

# %%
skincare_df = scrape_category(
    "cuidado-de-la-piel/cuidado-facial",
    "cuidado-de-la-piel",
    "cuidado-facial",
    "Skincare"
)
# Out:
# Scrapeando categoría: Skincare
# Página 1 procesada
# Página 2 procesada
# Fin de categoría.

# %%
df_total = pd.concat([makeup_df, skincare_df], ignore_index=True)

# %%
df_total["discount_%"] = (
    (df_total["list_price"] - df_total["price"])
    / df_total["list_price"]
) * 100

print("\nCantidad de productos por categoría:")
print(df_total["category"].value_counts())

print("\nPrecio promedio por categoría:")
print(df_total.groupby("category")["price"].mean())

print("\nPrecio máximo por categoría:")
print(df_total.groupby("category")["price"].max())

print("\nPromedio de descuento por categoría:")
print(df_total.groupby("category")["discount_%"].mean())
# Out:
# Cantidad de productos por categoría:
# category
# Maquillaje Rostro    63
# Skincare             14
# Name: count, dtype: int64
#
# Precio promedio por categoría:
# category
# Maquillaje Rostro    17619.047619
# Skincare             28071.428571
# Name: price, dtype: float64
#
# Precio máximo por categoría:
# category
# Maquillaje Rostro    130000
# Skincare             130000
# Name: price, dtype: int64
#
# Promedio de descuento por categoría:
# category
# Maquillaje Rostro    5.744520
# Skincare             9.319728
# Name: discount_%, dtype: float64

# %%
# Precio promedio
df_total.groupby("category")["price"].mean().plot(kind="bar")
plt.title("Precio Promedio: Maquillaje vs Skincare")
plt.ylabel("Precio")
plt.show()

# %%
# Distribución de precios
for cat in df_total["category"].unique():
    subset = df_total[df_total["category"] == cat]
    plt.hist(subset["price"], alpha=0.5, label=cat)

plt.legend()
plt.title("Distribución de Precios")
plt.show()

# %%
# Boxplot comparativo
df_total.boxplot(column="price", by="category")
plt.title("Boxplot de Precios por Categoría")
plt.suptitle("")
plt.show()

# %%
conn = sqlite3.connect("trendy_comparacion.db")
df_total.to_sql("productos", conn, if_exists="replace", index=False)
conn.commit()
conn.close()

print("\nBase de datos guardada como trendy_comparacion.db")
# Out:
# Base de datos guardada como trendy_comparacion.db

# %%
conn = sqlite3.connect("trendy_comparacion.db")

# Leer toda la tabla como DataFrame
df = pd.read_sql_query("SELECT * FROM productos", conn)
print(df)  # Muestra las primeras 5 filas

conn.close()
# Out:
#                                                  name   brand   price  \
# 0                    Kit Piel Mistic Face Ref KMF2247  Trendy   20000
# 1          Kit Mini Favoritos Galaxy 2026 Ref KMF2454  Trendy  130000
# 2                          Pin Stitch Guitarra DY2346  Trendy   12000
# 3            Kit Rubor y Gloss Pinky News Ref KPN2248  Trendy   15000
# 4           Corrector Hidrante Rebel Girl Ref CRG1420  Trendy   10000
# ..                                                ...     ...     ...
# 72  Protector Solar Facial 115ML Trendy Skin care ...  Trendy   50000
# 73        Doypack Serum Hidratante Morado Ref DSH1761  Trendy   10000
# 74     Sachet Protector Solar Facial 40ml Ref PSF1213  Trendy   20000
# 75         Colapsible Jabón Détox Pequeño Ref JDP1321  Trendy   12000
# 76              Doypack Jabón Détox 150ml Ref SJD1507  Trendy   15000
#
#     list_price           category  discount_%
# 0        20000  Maquillaje Rostro         0.0
# 1       130000  Maquillaje Rostro         0.0
# 2        12000  Maquillaje Rostro         0.0
# 3        15000  Maquillaje Rostro         0.0
# 4        10000  Maquillaje Rostro         0.0
# ..         ...                ...         ...
# 72       50000           Skincare         0.0
# 73       10000           Skincare         0.0
# 74       20000           Skincare         0.0
# 75       12000           Skincare         0.0
# 76       15000           Skincare         0.0
#
# [77 rows x 6 columns]
